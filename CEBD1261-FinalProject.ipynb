# %%
# %python
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mlflow_experiment_id = 866112
import mlflow
import mlflow.spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## IMPORT DATA FOR EDA
vg_data = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/vgsales.csv')
vg_data.createOrReplaceTempView("vgsales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT Genre, count(1) AS count FROM vgsales GROUP BY Genre ORDER BY count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Genre</th><th>count</th></tr></thead><tbody><tr><td>Action</td><td>3316</td></tr><tr><td>Sports</td><td>2346</td></tr><tr><td>Misc</td><td>1739</td></tr><tr><td>Role-Playing</td><td>1488</td></tr><tr><td>Shooter</td><td>1310</td></tr><tr><td>Adventure</td><td>1286</td></tr><tr><td>Racing</td><td>1249</td></tr><tr><td>Platform</td><td>886</td></tr><tr><td>Simulation</td><td>867</td></tr><tr><td>Fighting</td><td>848</td></tr><tr><td>Strategy</td><td>681</td></tr><tr><td>Puzzle</td><td>582</td></tr></tbody></table></div>

# %%
# %sql
SELECT Genre, sum(Global_Sales) AS sum FROM vgsales GROUP BY Genre ORDER BY sum DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Genre</th><th>sum</th></tr></thead><tbody><tr><td>Action</td><td>1751.1799999999691</td></tr><tr><td>Sports</td><td>1330.929999999988</td></tr><tr><td>Shooter</td><td>1037.3699999999901</td></tr><tr><td>Role-Playing</td><td>927.3699999999941</td></tr><tr><td>Platform</td><td>831.3699999999974</td></tr><tr><td>Misc</td><td>809.9599999999936</td></tr><tr><td>Racing</td><td>732.0399999999955</td></tr><tr><td>Fighting</td><td>448.90999999999923</td></tr><tr><td>Simulation</td><td>392.19999999999783</td></tr><tr><td>Puzzle</td><td>244.9500000000005</td></tr><tr><td>Adventure</td><td>239.04000000000138</td></tr><tr><td>Strategy</td><td>175.1200000000004</td></tr></tbody></table></div>

# %%
# %sql
SELECT Platform, sum(Global_Sales) AS sum FROM vgsales GROUP BY Platform ORDER BY sum DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Platform</th><th>sum</th></tr></thead><tbody><tr><td>PS2</td><td>1255.6399999999871</td></tr><tr><td>X360</td><td>979.9599999999996</td></tr><tr><td>PS3</td><td>957.8399999999987</td></tr><tr><td>Wii</td><td>926.7099999999971</td></tr><tr><td>DS</td><td>822.4899999999874</td></tr><tr><td>PS</td><td>730.659999999997</td></tr><tr><td>GBA</td><td>318.499999999998</td></tr><tr><td>PSP</td><td>296.2799999999948</td></tr><tr><td>PS4</td><td>278.0999999999994</td></tr><tr><td>PC</td><td>258.81999999999846</td></tr><tr><td>XB</td><td>258.25999999999834</td></tr><tr><td>GB</td><td>255.44999999999987</td></tr><tr><td>NES</td><td>251.06999999999988</td></tr><tr><td>3DS</td><td>247.4600000000001</td></tr><tr><td>N64</td><td>218.87999999999985</td></tr><tr><td>SNES</td><td>200.05000000000024</td></tr><tr><td>GC</td><td>199.3600000000007</td></tr><tr><td>XOne</td><td>141.05999999999995</td></tr><tr><td>2600</td><td>97.08000000000003</td></tr><tr><td>WiiU</td><td>81.86000000000006</td></tr><tr><td>PSV</td><td>61.93000000000005</td></tr><tr><td>SAT</td><td>33.59000000000002</td></tr><tr><td>GEN</td><td>28.360000000000003</td></tr><tr><td>DC</td><td>15.969999999999997</td></tr><tr><td>SCD</td><td>1.8700000000000003</td></tr><tr><td>NG</td><td>1.4400000000000004</td></tr><tr><td>WS</td><td>1.42</td></tr><tr><td>TG16</td><td>0.16</td></tr><tr><td>3DO</td><td>0.1</td></tr><tr><td>GG</td><td>0.04</td></tr><tr><td>PCFX</td><td>0.03</td></tr></tbody></table></div>

# %%
# %sql
SELECT Year, count(1) FROM vgsales GROUP BY Year ORDER BY Year
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>count(1)</th></tr></thead><tbody><tr><td>1980</td><td>9</td></tr><tr><td>1981</td><td>46</td></tr><tr><td>1982</td><td>36</td></tr><tr><td>1983</td><td>17</td></tr><tr><td>1984</td><td>14</td></tr><tr><td>1985</td><td>14</td></tr><tr><td>1986</td><td>21</td></tr><tr><td>1987</td><td>16</td></tr><tr><td>1988</td><td>15</td></tr><tr><td>1989</td><td>17</td></tr><tr><td>1990</td><td>16</td></tr><tr><td>1991</td><td>41</td></tr><tr><td>1992</td><td>43</td></tr><tr><td>1993</td><td>60</td></tr><tr><td>1994</td><td>121</td></tr><tr><td>1995</td><td>219</td></tr><tr><td>1996</td><td>263</td></tr><tr><td>1997</td><td>289</td></tr><tr><td>1998</td><td>379</td></tr><tr><td>1999</td><td>338</td></tr><tr><td>2000</td><td>349</td></tr><tr><td>2001</td><td>482</td></tr><tr><td>2002</td><td>829</td></tr><tr><td>2003</td><td>775</td></tr><tr><td>2004</td><td>763</td></tr><tr><td>2005</td><td>941</td></tr><tr><td>2006</td><td>1008</td></tr><tr><td>2007</td><td>1202</td></tr><tr><td>2008</td><td>1428</td></tr><tr><td>2009</td><td>1431</td></tr><tr><td>2010</td><td>1259</td></tr><tr><td>2011</td><td>1139</td></tr><tr><td>2012</td><td>657</td></tr><tr><td>2013</td><td>546</td></tr><tr><td>2014</td><td>582</td></tr><tr><td>2015</td><td>614</td></tr><tr><td>2016</td><td>344</td></tr><tr><td>2017</td><td>3</td></tr><tr><td>2020</td><td>1</td></tr><tr><td>N/A</td><td>271</td></tr></tbody></table></div>

# %%
# %python
## LOAD DATA INTO DATAFRAME
df=pd.read_csv('/dbfs/FileStore/tables/vgsales.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## VIEW AND CLEAN DATA
#Drop empty Publisher rows and fill empty Year rows with median
df.dropna(subset=['Publisher'], axis = 0, inplace=True)
df['Year'].fillna(df['Year'].median(), inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## PROCESSING AND FEATURE ENGINEERING
from sklearn.preprocessing import LabelEncoder
# Drop irrelevant data
df.drop('Name', axis=1, inplace=True)
df.drop('Rank', axis=1, inplace=True)
# Label encode categorical data
le = LabelEncoder()
df['Publisher'] = le.fit_transform(df['Publisher'])
df['Platform'] = le.fit_transform(df['Platform'])
df['Genre'] = le.fit_transform(df['Genre'])
# convert numerical data to float 16
df['Platform'] = df['Platform'].astype('float16')
df['Year'] = df['Year'].astype('float16')
df['Genre'] = df['Genre'].astype('float16')
df['Publisher'] = df['Publisher'].astype('float16')
df['NA_Sales'] = df['NA_Sales'].astype('float16')
df['EU_Sales'] = df['EU_Sales'].astype('float16')
df['JP_Sales'] = df['JP_Sales'].astype('float16')
df['Other_Sales'] = df['Other_Sales'].astype('float16')
df['Global_Sales'] = df['Global_Sales'].astype('float16')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## DEFINE TARGET AND FEATURES
y = np.array(df['Global_Sales'])
X = df.drop('Global_Sales', axis = 1)
feature_list = list(df.columns)
X = np.array(X)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Platform&#39;, &#39;Year&#39;, &#39;Genre&#39;, &#39;Publisher&#39;, &#39;NA_Sales&#39;, &#39;EU_Sales&#39;, &#39;JP_Sales&#39;, &#39;Other_Sales&#39;, &#39;Global_Sales&#39;]
# </div>

# %%
## SPLIT DATA INTO TEST AND TRAIN
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Run Models
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
    
def model_rf():
    model = RandomForestRegressor(
    n_estimators=100,
    max_depth= 10,
    random_state=2020,
    n_jobs=-1)
    return model
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pickle
import gc
def train_model (X_train, y_train):
    kf = KFold(5)
    for i, (tr_idx, vl_idx) in enumerate(kf.split(X_train, y_train)):
        print('FOLD {} \n'.format(i))
        X_tr, y_tr = X_train[tr_idx], y_train[tr_idx]
        X_vl, y_vl = X_train[vl_idx], y_train[vl_idx]
        model = model_rf()
        model.fit(X_tr, y_tr)
        with open('rf_model_{}.pkl'.format(i), 'wb') as handle:
            pickle.dump(model, handle)
        handle.close()
        del model, X_tr, X_vl
        gc.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_model(X_train=X_train, y_train=y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FOLD 0
#
# FOLD 1
#
# FOLD 2
#
# FOLD 3
#
# FOLD 4
#
# </div>

# %%
## EVALUATE MODELS
MAEscore = []
accuracyscore = []
predictions = []
for i in range(5):
    infile = open('rf_model_{}.pkl'.format(i), 'rb')
    model = pickle.load(infile)
    infile.close()
    prediction = model.predict(X_test)
    predictions.append(prediction)
    errors = abs(predictions - y_test)
    meanerrors = round(np.mean(errors), 2)
    MAEscore.append(meanerrors)
    mape = np.mean(100 * (errors/y_test))
    accuracy = 100 - mape
    accuracyscore.append(accuracy)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## VISUALIZE FEATURE IMPORTANCES
importances = list(model.feature_importances_)
feature_importances = [(feature, round(importances, 2)) for feature, importances in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Variable: NA_Sales             Importance: 0.83
# Variable: EU_Sales             Importance: 0.12
# Variable: Other_Sales          Importance: 0.03
# Variable: JP_Sales             Importance: 0.02
# Variable: Platform             Importance: 0.0
# Variable: Year                 Importance: 0.0
# Variable: Genre                Importance: 0.0
# Variable: Publisher            Importance: 0.0
# </div>

# %%
# Plot
plt.style.use('fivethirtyeight')
x_values = list(range(len(importances)))
plt.bar(x_values, importances, orientation='vertical')
plt.xticks(x_values, feature_list, rotation='vertical')
plt.ylabel('Importance')
plt.xlabel('Variable')
plt.title('Variable Importances')

# %%
## VISUSALIZE PREDICTIONS
import datetime
#years = X[:, feature_list.index('Year')]
years_test = X_test[:, feature_list.index('Year')]
true_data = pd.DataFrame(data = {'Year': years_test, 'actual': y_test})
true_data = true_data.groupby(["Year"])["actual"].sum()
predictions = np.mean(predictions, axis=0)
predictions_data = pd.DataFrame(data = {'Year': years_test, 'prediction': predictions})
predictions_data = predictions_data.groupby(["Year"])["prediction"].sum()
plt.plot(true_data, label = 'actual')
plt.plot(predictions_data, label = 'prediction')
plt.legend()
plt.xlabel ('Year')
plt.ylabel ('Global Sales (in millions)')
plt.title('Actual and Predicted Sales')
